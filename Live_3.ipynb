# %%
import pandas as pd

df = pd.read_csv("ibm-common-stock-closing-prices.csv")

# %%
df.info
# Out:
# <bound method DataFrame.info of                                  Date  IBM common stock closing prices
# 0                          1962-01-02                           572.00
# 1                          1962-01-03                           577.00
# 2                          1962-01-04                           571.25
# 3                          1962-01-05                           560.00
# 4                          1962-01-08                           549.50
# 5                          1962-01-09                           556.00
# 6                          1962-01-10                           557.00
# 7                          1962-01-11                           563.00
# 8                          1962-01-12                           564.00
# 9                          1962-01-15                           566.50
# 10                         1962-01-16                           560.50
# 11                         1962-01-17                           551.50
# ...

# %%
df = df[:-1]
df.tail()
# Out:
#             Date  IBM common stock closing prices
# 1001  1965-12-22                           505.75
# 1002  1965-12-23                           499.00
# 1003  1965-12-27                           500.00
# 1004  1965-12-28                           502.25
# 1005  1965-12-29                           498.00

# %%
# %matplotlib inline
df.plot()

# %%
from datetime import datetime

dates= df.Date

# %%
prices = df['IBM common stock closing prices']

# %%
pd.date_range(start = dates[0], end = dates[500])
# Out:
# DatetimeIndex(['1962-01-02', '1962-01-03', '1962-01-04', '1962-01-05',
#                '1962-01-06', '1962-01-07', '1962-01-08', '1962-01-09',
#                '1962-01-10', '1962-01-11',
#                ...
#                '1963-12-18', '1963-12-19', '1963-12-20', '1963-12-21',
#                '1963-12-22', '1963-12-23', '1963-12-24', '1963-12-25',
#                '1963-12-26', '1963-12-27'],
#               dtype='datetime64[ns]', length=725, freq='D')

# %%
df[:500].plot()

# %%
df[500:].plot()

# %%
df[100:500].plot()

# %%
df[100:150].plot()

# %%
df[150:175].plot()

# %%
df[150:160].plot()

# %%
df[154:164]

# %%
poi = df[50:600]
poi.plot()

# %%
focus = df[100:600]
focus.plot()

# %%
import plotly

plotly.tools.set_credentials_file(username='DaveSamuel', api_key='KkkN9oZ0XxLTp37cuDnE')

# %%
import plotly.plotly as py
import plotly.graph_objs as go

data = [go.Scatter( x=dates, y=prices )]

py.iplot(data, filename='pandas-time-series')
# Out:
# High five! You successfuly sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~DaveSamuel/0 or inside your plot.ly account where it is named 'pandas-time-series'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~DaveSamuel/0.embed" height="525px" width="100%"></iframe>
